# %%
import pandas as pd

# %%
jan_df = pd.read_csv('raw data/JC-201901-citibike-tripdata.csv')
jan_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...             ...                       ...                       ...
# 19671           853  2019-01-26 06:40:17.3320  2019-01-26 06:54:30.8880
# 19672           936  2019-01-27 06:36:20.6400  2019-01-27 06:51:57.1460
# 19673           653  2019-01-27 21:14:08.5460  2019-01-27 21:25:01.6170
# 19674           960  2019-01-29 06:15:26.5880  2019-01-29 06:31:26.7300
# 19675          1109  2019-01-30 06:30:03.6050  2019-01-30 06:48:33.2760
#
#        start station id start station name  start station latitude  \
# ...

# %%
feb_df = pd.read_csv('raw data/JC-201902-citibike-tripdata.csv')
mar_df = pd.read_csv('raw data/JC-201903-citibike-tripdata.csv')
apr_df = pd.read_csv('raw data/JC-201904-citibike-tripdata.csv')
may_df = pd.read_csv('raw data/JC-201905-citibike-tripdata.csv')
jun_df = pd.read_csv('raw data/JC-201906-citibike-tripdata.csv')
jul_df = pd.read_csv('raw data/JC-201907-citibike-tripdata.csv')
aug_df = pd.read_csv('raw data/JC-201908-citibike-tripdata.csv')
sep_df = pd.read_csv('raw data/JC-201909-citibike-tripdata.csv')
oct_df = pd.read_csv('raw data/JC-201910-citibike-tripdata.csv')
nov_df = pd.read_csv('raw data/JC-201911-citibike-tripdata.csv')
dec_df = pd.read_csv('raw data/JC-201912-citibike-tripdata.csv')

# %%
year2019 = [jan_df, feb_df, mar_df, apr_df, may_df, jun_df, jul_df, aug_df, sep_df, oct_df, nov_df, dec_df]
year2019
# Out:
# [       tripduration                 starttime                  stoptime  \
#  0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
#  1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
#  2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
#  3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
#  4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#  ...             ...                       ...                       ...
#  19671           853  2019-01-26 06:40:17.3320  2019-01-26 06:54:30.8880
#  19672           936  2019-01-27 06:36:20.6400  2019-01-27 06:51:57.1460
#  19673           653  2019-01-27 21:14:08.5460  2019-01-27 21:25:01.6170
#  19674           960  2019-01-29 06:15:26.5880  2019-01-29 06:31:26.7300
#  19675          1109  2019-01-30 06:30:03.6050  2019-01-30 06:48:33.2760
#
#         start station id start station name  start station latitude  \
# ...

# %%
year2019_df = pd.concat(year2019)
year2019_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...             ...                       ...                       ...
# 19723           283  2019-12-31 23:12:18.5480  2019-12-31 23:17:01.8740
# 19724           267  2019-12-31 23:19:03.5840  2019-12-31 23:23:30.6640
# 19725           379  2019-12-31 23:19:06.5830  2019-12-31 23:25:25.7970
# 19726           188  2019-12-31 23:24:00.2630  2019-12-31 23:27:09.0400
# 19727           326  2019-12-31 23:45:20.9780  2019-12-31 23:50:47.7490
#
#        start station id start station name  start station latitude  \
# ...

# %%
# exploring for types of data
year2019_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# checking for missing values
year2019_df.count()
# Out:
# tripduration               404947
# starttime                  404947
# stoptime                   404947
# start station id           404947
# start station name         404947
# start station latitude     404947
# start station longitude    404947
# end station id             404947
# end station name           404947
# end station latitude       404947
# end station longitude      404947
# bikeid                     404947
# usertype                   404947
# birth year                 404947
# gender                     404947
# dtype: int64

# %%
year2019_df.to_csv("raw data/all_2019.csv", index=False, header=True)
